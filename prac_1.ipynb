# %%
class Chocolate:
    def __init__(self, price: float, additive: str = None):
        if price <= 0:
            raise ValueError("Цена должна быть больше нуля")
        self.price = price
        self.additive = additive

    def show_my_chocolate(self):
        if self.additive:
            print(f"Шоколадный батончик, добавка: {self.additive}")
        else:
            print("Обычный шоколадный батончик")

    def __str__(self):
        return f"Шоколадный батончик, {self.price} рублей"


try:
    bar1 = Chocolate(49.99)
    bar1.show_my_chocolate()
    print(bar1)

    bar2 = Chocolate(89.90, "орехи")
    bar2.show_my_chocolate()
    print(bar2)

    bar3 = Chocolate(-10.0)

except ValueError as e:
    print(f"Ошибка: {e}")
# Out:
# Обычный шоколадный батончик
# Шоколадный батончик, 49.99 рублей
# Шоколадный батончик, добавка: орехи
# Шоколадный батончик, 89.9 рублей
# Ошибка: Цена должна быть больше нуля
